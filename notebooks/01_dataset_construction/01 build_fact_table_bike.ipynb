# %%
from pyspark.sql import functions as F
from pyspark.sql.functions import to_date

# %% [markdown]
# # BICICLETAS

# %% [markdown]
# **TABLA fact_bike**
#
# **Objetivo: Crear una tabla de hechos con los datos de bicicletas**

# %% [markdown]
# 1) Crear tabla fact_bike

# %%
#Mantendré solo las columnas started_date, start_station_id, end_station_id y total. Las columnas de nombres vendrán de la tabla dim_station utilizando los ids de inicio y final.

fact_bike = (
    spark.table("hive_metastore.tfm.datos_brutos_bike")
    .select(
        "started_date",
        "start_station_id",
        "end_station_id",
        "start_lat",
        "start_lng",
        "end_lat",
        "end_lng",
        "total"
    )
    .withColumn("started_date", to_date("started_date"))    
)

display(fact_bike.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>started_date</th><th>start_station_id</th><th>end_station_id</th><th>start_lat</th><th>start_lng</th><th>end_lat</th><th>end_lng</th><th>total</th></tr></thead><tbody><tr><td>2019-01-19</td><td>7311.02</td><td>7540.02</td><td>40.782939</td><td>-73.978652</td><td>40.794566</td><td>-73.936254</td><td>1</td></tr><tr><td>2019-02-10</td><td>7738.04</td><td>SYS035</td><td>40.809495</td><td>-73.947765</td><td>40.72866</td><td>-74.01198</td><td>1</td></tr><tr><td>2019-03-29</td><td>5523.02</td><td>7858.02</td><td>40.722293</td><td>-73.991475</td><td>40.817166</td><td>-73.914737</td><td>1</td></tr><tr><td>2019-04-02</td><td>5746.14</td><td>SYS014</td><td>40.729538</td><td>-73.984267</td><td>40.716444</td><td>-73.982331</td><td>1</td></tr><tr><td>2019-04-08</td><td>5297.02</td><td>7311.02</td><td>40.715338</td><td>-74.016584</td><td>40.782939</td><td>-73.978652</td><td>1</td></tr><tr><td>2019-04-12</td><td>6912.01</td><td>SYS035</td><td>40.766741</td><td>-73.979069</td><td>40.72866</td><td>-74.01198</td><td>1</td></tr><tr><td>2019-04-18</td><td>4461.04</td><td>SYS035</td><td>40.689407</td><td>-73.968855</td><td>40.72866</td><td>-74.01198</td><td>1</td></tr><tr><td>2019-04-18</td><td>7756.10</td><td>7971.07</td><td>40.811432</td><td>-73.951878</td><td>40.82281</td><td>-73.937413</td><td>1</td></tr><tr><td>2019-04-18</td><td>4617.01</td><td>SYS035</td><td>40.692371</td><td>-73.937054</td><td>40.72866</td><td>-74.01198</td><td>1</td></tr><tr><td>2019-04-21</td><td>4936.01</td><td>SYS035</td><td>40.702551</td><td>-73.989402</td><td>40.72866</td><td>-74.01198</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# 2. Calcular distancia entre las estaciones de inicio y fin

# %%
fact_bike = (
    fact_bike
    .withColumn(
        "distancia",
        2 * 6371 * F.asin(
            F.sqrt(
                F.pow(
                    F.sin((F.radians(F.col("end_lat")) - F.radians(F.col("start_lat"))) / 2),
                    2
                ) +
                F.cos(F.radians(F.col("start_lat"))) *
                F.cos(F.radians(F.col("end_lat"))) *
                F.pow(
                    F.sin((F.radians(F.col("end_lng")) - F.radians(F.col("start_lng"))) / 2),
                    2
                )
            )
        )
    ).drop('start_lat', 'end_lat', 'start_lng', 'end_lng')
)

# %%
display(fact_bike.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>started_date</th><th>start_station_id</th><th>end_station_id</th><th>total</th><th>distancia</th></tr></thead><tbody><tr><td>2022-10-25</td><td>5636.11</td><td>5190.07</td><td>1</td><td>1.7163172839369876</td></tr><tr><td>2022-10-25</td><td>4028.04</td><td>3905.15</td><td>1</td><td>0.7168435285935274</td></tr><tr><td>2022-10-25</td><td>6459.04</td><td>5190.07</td><td>1</td><td>4.384248964768999</td></tr><tr><td>2022-10-25</td><td>8353.02</td><td>8316.02</td><td>1</td><td>0.175753197253727</td></tr><tr><td>2022-10-25</td><td>7602.05</td><td>6779.04</td><td>1</td><td>4.816698458138459</td></tr><tr><td>2022-10-25</td><td>6206.08</td><td>6611.05</td><td>1</td><td>1.9143069730841213</td></tr><tr><td>2022-10-25</td><td>5805.05</td><td>5922.08</td><td>3</td><td>0.5363583383621947</td></tr><tr><td>2022-10-25</td><td>5653.12</td><td>5351.03</td><td>1</td><td>1.2791972975368637</td></tr><tr><td>2022-10-25</td><td>6364.07</td><td>6890.06</td><td>2</td><td>1.7722705929554525</td></tr><tr><td>2022-10-25</td><td>5270.08</td><td>6602.03</td><td>1</td><td>4.727696652746611</td></tr></tbody></table></div>

# %%
#Por último, antes de guardar renomear nombres de columnas para que sea más sencillo entender las tablas

fact_bike = (
    fact_bike
    .withColumnRenamed('start_station_id','bike_start_station_id')
    .withColumnRenamed('end_station_id','bike_end_station_id')
)

# %%
display(fact_bike.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>started_date</th><th>bike_start_station_id</th><th>bike_end_station_id</th><th>total</th><th>distancia</th></tr></thead><tbody><tr><td>2022-10-25</td><td>5636.11</td><td>5190.07</td><td>1</td><td>1.7163172839369876</td></tr><tr><td>2022-10-25</td><td>4028.04</td><td>3905.15</td><td>1</td><td>0.7168435285935274</td></tr><tr><td>2022-10-25</td><td>6459.04</td><td>5190.07</td><td>1</td><td>4.384248964768999</td></tr><tr><td>2022-10-25</td><td>8353.02</td><td>8316.02</td><td>1</td><td>0.175753197253727</td></tr><tr><td>2022-10-25</td><td>7602.05</td><td>6779.04</td><td>1</td><td>4.816698458138459</td></tr><tr><td>2022-10-25</td><td>6206.08</td><td>6611.05</td><td>1</td><td>1.9143069730841213</td></tr><tr><td>2022-10-25</td><td>5805.05</td><td>5922.08</td><td>3</td><td>0.5363583383621947</td></tr><tr><td>2022-10-25</td><td>5653.12</td><td>5351.03</td><td>1</td><td>1.2791972975368637</td></tr><tr><td>2022-10-25</td><td>6364.07</td><td>6890.06</td><td>2</td><td>1.7722705929554525</td></tr><tr><td>2022-10-25</td><td>5270.08</td><td>6602.03</td><td>1</td><td>4.727696652746611</td></tr></tbody></table></div>

# %% [markdown]
# 2) Crear tabla agg para facilitar futuros calculos

# %%
fact_bike_agg_station = (
    fact_bike
    .select(
        F.col('started_date').alias('date'),
        'bike_start_station_id',
        'total',
        'distancia'
    )
    .groupBy(
        'date',
        'bike_start_station_id'
    )
    .agg(
        F.sum('total').alias('sum_total'),
        F.avg('total').alias('avg_total'),
        F.sum('distancia').alias('sum_distancia'),
        F.avg('distancia').alias('avg_distancia')
    )
)

# %%
fact_bike_agg_station.count()
# Out:
# 2876674

# %%
fact_bike_agg = (
    fact_bike
    .select(
        F.col('started_date').alias('date'),
        'total',
        'distancia'
    )
    .groupBy('date')
    .agg(
        F.sum('total').alias('sum_total'),
        F.avg('total').alias('avg_total'),
        F.sum('distancia').alias('sum_distancia'),
        F.avg('distancia').alias('avg_distancia')
    )
)

# %%
fact_bike_agg.count()
# Out:
# 1993

# %% [markdown]
# 3) Guardar tabla fact_bike en el catalogo

# %%
fact_bike_agg_station.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("tfm.fact_bike_agg_station")

# %%
fact_bike_agg.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("tfm.fact_bike_agg")

# %%
fact_bike.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("tfm.fact_bike")
