# %% [markdown]
# #CONEXIÓN A AZURE

# %%
spark.conf.set(
  "fs.azure.account.key.masterrdp001sta.dfs.core.windows.net",
  "ubrM/TOROC6KRdGhHI04+8tXLRbVdnrsYAIEKoGkiI1LVta7uERw8AgT6YtqbrukLsjX5gJzKcqz+AStS8tZSA=="
)

# %% [markdown]
# #CREAR DATABASE

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS tfm")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[]</div>

# %% [markdown]
# # CREAR TABLAS

# %% [markdown]
# ## 1. BICICLETAS

# %%
datos_brutos_bike = spark.read.option("inferSchema", "true")\
    .option("header", "true")\
    .parquet("abfss://datos@masterrdp001sta.dfs.core.windows.net/citibike.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(datos_brutos_bike.limit(100))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
datos_brutos_bike.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("tfm.datos_brutos_bike")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# ...

# %% [markdown]
# ## 2. METRO

# %%
datos_brutos_metro = spark.read.option("inferSchema", "true")\
    .option("header", "true")\
    .csv("abfss://datos@masterrdp001sta.dfs.core.windows.net/mta_metro_ridership.csv")

# %%
display(datos_brutos_metro.limit(100))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
datos_brutos_metro.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("tfm.datos_brutos_metro")

# %% [markdown]
# ## 3. AUTOBUS

# %%
datos_brutos_bus = spark.read.option("inferSchema", "true")\
    .option("header", "true")\
    .csv("abfss://datos@masterrdp001sta.dfs.core.windows.net/mta_bus_ridership.csv")

# %%
display(datos_brutos_bus.limit(100))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
datos_brutos_bus.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("tfm.datos_brutos_bus")

# %% [markdown]
# ##4. CLIMA

# %%
datos_brutos_weather = spark.read.option("inferSchema", "true")\
    .option("header", "true")\
    .csv("abfss://datos@masterrdp001sta.dfs.core.windows.net/nyc_weather.csv")

# %%
display(datos_brutos_weather.limit(100))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
datos_brutos_weather.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("tfm.datos_brutos_weather")

# %% [markdown]
# ##5. FESTIVOS

# %%
datos_brutos_holidays = spark.read.option("inferSchema", "true")\
    .option("header", "true")\
    .csv("abfss://datos@masterrdp001sta.dfs.core.windows.net/nyc_holidays_2020_2024.csv")

# %%
display(datos_brutos_holidays)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
datos_brutos_holidays.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("tfm.datos_brutos_holidays")
