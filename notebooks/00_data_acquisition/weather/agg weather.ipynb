# %%
from pathlib import Path
import pandas as pd

def empilhar_csvs(pasta_csv: str, padrao: str = "*.csv") -> pd.DataFrame:
   
    arquivos = sorted(Path(pasta_csv).glob(padrao))
    if not arquivos:
        raise FileNotFoundError(f"Nenhum CSV encontrado em {pasta_csv} com padrão {padrao}")

    
    dfs = (
        pd.read_csv(
            arq,
            dtype_backend="pyarrow", 
            low_memory=False
        )
        for arq in arquivos
    )
    df = pd.concat(dfs, ignore_index=True)
    return df

# %%
pasta = r"C:\Riguel\Master\Clases\TFM\Enviar\Notebooks Python\weather"

df = empilhar_csvs(pasta)

# %%
df.head(100)
# Out:
#         STATION                              NAME        DATE   AWND  PGTM  \
# 0   USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-01-01  17.67  <NA>
# 1   USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-01-02   9.62  <NA>
# 2   USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-01-03   6.49  <NA>
# 3   USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-01-04   8.28  <NA>
# 4   USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-01-05  21.47  <NA>
# ..          ...                               ...         ...    ...   ...
# 95  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-04-05   5.82  <NA>
# 96  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-04-06   8.72  <NA>
# 97  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-04-07  10.51  <NA>
# 98  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-04-08   9.62  <NA>
# 99  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-04-09  14.99  <NA>
#
#     PRCP  SNOW  SNWD  TAVG  TMAX  ...  WDF5_ATTRIBUTES  WSF2_ATTRIBUTES  \
# 0    0.0   0.0   0.0    40  42.0  ...             <NA>             <NA>
# 1    0.0   0.0   0.0    38  48.0  ...             <NA>             <NA>
# 2   0.13   0.0   0.0    44  48.0  ...             <NA>             <NA>
# 3   0.16   0.0   0.0    47  51.0  ...             <NA>             <NA>
# 4    0.0   0.0   0.0    41  49.0  ...             <NA>             <NA>
# ..   ...   ...   ...   ...   ...  ...              ...              ...
# 95   0.0   0.0   0.0    48  58.0  ...             <NA>             <NA>
# 96  0.06   0.0   0.0    53  63.0  ...             <NA>             <NA>
# 97   0.0   0.0   0.0    54  63.0  ...             <NA>             <NA>
# 98  0.18   0.0   0.0    55  64.0  ...             <NA>             <NA>
# 99  0.13   0.0   0.0    50  58.0  ...             <NA>             <NA>
#
#     WSF5_ATTRIBUTES  WT01_ATTRIBUTES  WT02_ATTRIBUTES  WT03_ATTRIBUTES  \
# 0              <NA>             <NA>             <NA>             <NA>
# 1              <NA>             <NA>             <NA>             <NA>
# 2              <NA>             <NA>             <NA>             <NA>
# 3              <NA>             <NA>             <NA>             <NA>
# 4              <NA>             <NA>             <NA>             <NA>
# ..              ...              ...              ...              ...
# 95             <NA>             <NA>             <NA>             <NA>
# 96             <NA>             <NA>             <NA>             <NA>
# 97             <NA>             <NA>             <NA>             <NA>
# 98             <NA>             <NA>             <NA>             <NA>
# 99             <NA>             <NA>             <NA>             <NA>
#
#     WT04_ATTRIBUTES  WT05_ATTRIBUTES  WT06_ATTRIBUTES  WT08_ATTRIBUTES
# 0              <NA>             <NA>             <NA>             <NA>
# 1              <NA>             <NA>             <NA>             <NA>
# 2              <NA>             <NA>             <NA>             <NA>
# 3              <NA>             <NA>             <NA>             <NA>
# 4              <NA>             <NA>             <NA>             <NA>
# ..              ...              ...              ...              ...
# 95             <NA>             <NA>             <NA>             <NA>
# 96             <NA>             <NA>             <NA>             <NA>
# 97             <NA>             <NA>             <NA>             <NA>
# 98             <NA>             <NA>             <NA>             <NA>
# 99             <NA>             <NA>             <NA>             <NA>
#
# [100 rows x 47 columns]

# %%
len(df)
# Out:
# 7308

# %%
df.to_csv("nyc_weather.csv", index=False)
print("✅ Arquivo salvo com sucesso!")
# Out:
# ✅ Arquivo salvo com sucesso!

# %%
import pandas as pd


caminho = r"C:\Riguel\Master\Clases\TFM\Enviar\Notebooks Python\weather\nyc_weather.csv"


df = pd.read_csv(caminho)

# %%
display(df)
# Out:
#           STATION                              NAME        DATE   AWND  \
# 0     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-01-01  17.67
# 1     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-01-02   9.62
# 2     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-01-03   6.49
# 3     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-01-04   8.28
# 4     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-01-05  21.47
# ...           ...                               ...         ...    ...
# 7303  USW00094728       NY CITY CENTRAL PARK, NY US  2024-12-27   0.50
# 7304  USW00094728       NY CITY CENTRAL PARK, NY US  2024-12-28   0.60
# 7305  USW00094728       NY CITY CENTRAL PARK, NY US  2024-12-29   2.10
# 7306  USW00094728       NY CITY CENTRAL PARK, NY US  2024-12-30   2.90
# 7307  USW00094728       NY CITY CENTRAL PARK, NY US  2024-12-31   2.30
#
#         PGTM   PRCP  SNOW  SNWD  TAVG  TMAX  ...  WDF5_ATTRIBUTES  \
# 0        NaN   0.00   0.0   0.0  40.0  42.0  ...              NaN
# 1        NaN   0.00   0.0   0.0  38.0  48.0  ...              NaN
# 2        NaN   0.13   0.0   0.0  44.0  48.0  ...              NaN
# 3        NaN   0.16   0.0   0.0  47.0  51.0  ...              NaN
# 4        NaN   0.00   0.0   0.0  41.0  49.0  ...              NaN
# ...      ...    ...   ...   ...   ...   ...  ...              ...
# 7303  2308.0   0.00   0.0  30.0   NaN   6.7  ...              ,,W
# 7304    46.0  14.20   0.0   0.0   NaN  12.2  ...              ,,W
# 7305  2051.0   4.10   0.0   0.0   NaN  15.6  ...              ,,W
# 7306  1224.0   9.40   0.0   0.0   NaN  14.4  ...              ,,W
# 7307  2133.0  10.20   0.0   0.0   NaN  11.7  ...              ,,W
#
#       WSF2_ATTRIBUTES  WSF5_ATTRIBUTES  WT01_ATTRIBUTES  WT02_ATTRIBUTES  \
# 0                 NaN              NaN              NaN              NaN
# 1                 NaN              NaN              NaN              NaN
# 2                 NaN              NaN              NaN              NaN
# 3                 NaN              NaN              NaN              NaN
# 4                 NaN              NaN              NaN              NaN
# ...               ...              ...              ...              ...
# 7303              ,,W              ,,W              NaN              NaN
# 7304              ,,W              ,,W              ,,W              NaN
# 7305              ,,W              ,,W              NaN              NaN
# 7306              ,,W              ,,W              NaN              NaN
# 7307              ,,W              ,,W              NaN              NaN
#
#       WT03_ATTRIBUTES  WT04_ATTRIBUTES  WT05_ATTRIBUTES  WT06_ATTRIBUTES  \
# 0                 NaN              NaN              NaN              NaN
# 1                 NaN              NaN              NaN              NaN
# 2                 NaN              NaN              NaN              NaN
# 3                 NaN              NaN              NaN              NaN
# 4                 NaN              NaN              NaN              NaN
# ...               ...              ...              ...              ...
# 7303              NaN              NaN              NaN              NaN
# 7304              NaN              NaN              NaN              NaN
# 7305              NaN              NaN              NaN              NaN
# 7306              NaN              NaN              NaN              NaN
# 7307              NaN              NaN              NaN              NaN
#
#       WT08_ATTRIBUTES
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 7303              NaN
# 7304              ,,W
# 7305              ,,W
# 7306              NaN
# 7307              NaN
#
# [7308 rows x 47 columns]
